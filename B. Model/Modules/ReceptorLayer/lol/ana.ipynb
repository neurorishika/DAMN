# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt4
# Out:
# Warning: Cannot change to a different GUI toolkit: qt4. Using nbagg instead.

# %%
a1 = np.load('Conc_1_Angle_0.00_Type_reference_Dimension_2.odor_current_input.npy')
a2 = np.load('Conc_0.8_Angle_0.00_Type_reference_Dimension_2.odor_current_input.npy')
b = np.load('Conc_1_Angle_90.00_Type_90_Dimension_2.odor_current_input.npy')
c = np.load('Conc_1_Angle_180.00_Type_180_Dimension_2.odor_current_input.npy')

# %%
from sklearn.decomposition import PCA

# %%
model = PCA(n_components=3)

# %%
model.fit(b.T)
model.fit(c.T)
model.fit(a1.T)
model.fit(a2.T)

a1 = model.transform(a1.T)
a2 = model.transform(a2.T)
b = model.transform(b.T)
c = model.transform(c.T)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = plt.figure()
fig.patch.set_alpha(0.0)
ax = fig.add_subplot(111, projection='3d')
ax.patch.set_alpha(0.0)
ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax.plot(a1[:,0],a1[:,1],a1[:,2],label='Odor A1')
ax.plot(a2[:,0],a2[:,1],a2[:,2],label='Odor A2')
ax.plot(b[:,0],b[:,1],b[:,2],label='Odor B')
ax.plot(c[:,0],c[:,1],c[:,2],label='Odor C')
ax.grid(False)
#plt.axis('off')
plt.legend(frameon=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
model.explained_variance_ratio_
# Out:
# array([0.85279488, 0.09076071, 0.02894772])
